# %% [markdown]
# # Setting up & load data

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import math


# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# warnings handler
import warnings
warnings.filterwarnings("ignore")

# data
df = pd.read_csv("data/loans_2007.csv")

# %% [markdown]
# # Business Understanding

# %% [markdown]
# The purpose of the analysis is to reduce defaults, improve profitability and help the company and investors determine interest rates. We will use machine learning models to analyze credit risk as a binary classification problem.

# %% [markdown]
# ## Background

# %% [markdown]
# So ein paar Definitionen was ist LENDERS CLUB, was ist PEER to PEER LEDNING, AREA.

# %% [markdown]
# ## Key Question

# %% [markdown]
# 1. How to avoid default?
# 2. How to set interst rates?
# 3. How to improve profitibility?
# 4. How to choose the Performance metrics?
#
# Bonus: What are fair credits - these that can not be taken - at a private banks, but high impact?
#        Based on scenario, high intresst in social impact - less in payback

# %% [markdown]
# ## Feature glossary & label

# %%
# label "loan_status"
df.loan_status.value_counts()
# Out:
# Fully Paid                                             33136
# Charged Off                                             5634
# Does not meet the credit policy. Status:Fully Paid      1988
# Current                                                  961
# Does not meet the credit policy. Status:Charged Off      761
# Late (31-120 days)                                        24
# In Grace Period                                           20
# Late (16-30 days)                                          8
# Default                                                    3
# Name: loan_status, dtype: int64

# %% [markdown]
# There are many LendingClub data sets on Kaggle. Here is the information on this particular data set:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_amnt</td>
#       <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>term</td>
#       <td>The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>int_rate</td>
#       <td>Interest Rate on the loan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>installment</td>
#       <td>The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>grade</td>
#       <td>LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sub_grade</td>
#       <td>LC assigned loan subgrade</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>emp_title</td>
#       <td>The job title supplied by the Borrower when applying for the loan.*</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>emp_length</td>
#       <td>Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>home_ownership</td>
#       <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>annual_inc</td>
#       <td>The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>verification_status</td>
#       <td>Indicates if income was verified by LC, not verified, or if the income source was verified</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>issue_d</td>
#       <td>The month which the loan was funded</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>loan_status</td>
#       <td>Current status of the loan</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>purpose</td>
#       <td>A category provided by the borrower for the loan request.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>title</td>
#       <td>The loan title provided by the borrower</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>zip_code</td>
#       <td>The first 3 numbers of the zip code provided by the borrower in the loan application.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>addr_state</td>
#       <td>The state provided by the borrower in the loan application</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dti</td>
#       <td>A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>earliest_cr_line</td>
#       <td>The month the borrower's earliest reported credit line was opened</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>open_acc</td>
#       <td>The number of open credit lines in the borrower's credit file.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>pub_rec</td>
#       <td>Number of derogatory public records</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>revol_bal</td>
#       <td>Total credit revolving balance</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>revol_util</td>
#       <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>total_acc</td>
#       <td>The total number of credit lines currently in the borrower's credit file</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>initial_list_status</td>
#       <td>The initial listing status of the loan. Possible values are – W, F</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>application_type</td>
#       <td>Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>mort_acc</td>
#       <td>Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>Number of public record bankruptcies</td>
#     </tr>
#   </tbody>
# </table>
#
#
# ---

# %% [markdown]
# Fehlt in der Tabell, kann ergänzt werden
#
# id - credit id
# **member_id to check for dublicates** - member_id
# 'funded_amnt', - credit amount
# 'funded_amnt_inv' - total amount of investment eigenanteil + kredit ?
# pymnt_plan - monthly, yearly - check in df viele n einige NaN drop? Why not?
# delinq_2yrs - straffällig in den letzten zwei jahren
# inq_last6months - credit inquiery = A credit inquiry is a request by an institution for credit report information from a credit reporting agency.
#
# 'out_prncp', - outstanding principal
# 'out_prncp_inv', - siehe invest ?
#        'total_pymnt', - stand der rückzahlung
#        'total_pymnt_inv', - ?
#        'total_rec_prncp', - recovery?
#        'total_rec_int', -
#        'total_rec_late_fee', -
#        'recoveries', - recoveries
#        'collection_recovery_fee', - mahngebühr bezahlt
#        'last_pymnt_d', - last payment date
#        'last_pymnt_amnt', - last payment ammount
#        'last_credit_pull_d', - last credit bezug (wenn dir schon mal was gegeben wurde, das date)
#        'collections_12_mths_ex_med', - Number of collections in 12 months excluding medical collections.
#        'policy_code' - ? Missing ? if more than 3 min drop
#
#        'acc_now_delinq', - The Number of accounts on which the borrower is now delinquent.
#        'chargeoff_within_12_mths', - Number of charge-offs within 12 months.
#        'delinq_amnt', - The past-due amount owed for the accounts on which the borrower is now delinquent
#        'tax_liens' - Number of tax liens

# %% [markdown]
# Hier sind alle definitionen des LendersClub https://www.lendingclub.com/developers/listed-loans
#
# <table>
#             <thead>
#             <tr><th>Name</th><th>Type</th><th>Nullable</th><th>Description</th></tr>
#             </thead>
#             <tbody>
#             <tr>
#             <td>AsOfDate</td>
#             <td>String</td>
#             <td>No</td>
#             <td>As of date</td>
#             </tr>
#             <tr>
#             <td>id</td>
#             <td>Integer</td>
#             <td>No</td>
#             <td>A unique LC assigned ID for the loan listing.</td>
#             </tr>
#             <tr>
#             <td>memberId</td>
#             <td>Integer</td>
#             <td>No</td>
#             <td>A unique LC assigned Id for the borrower member.</td>
#             </tr>
#             <tr>
#             <td>term</td>
#             <td>Integer</td>
#             <td>No</td>
#             <td>The Number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#             </tr>
#             <tr>
#             <td>intRate</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>Interest Rate on the loan</td>
#             </tr>
#             <tr>
#             <td>expDefaultRate</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>The expected default rate of the loan.</td>
#             </tr>
#             <tr>
#             <td>serviceFeeRate</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>Service fee rate paid by the investor for this loan.</td>
#             </tr>
#             <tr>
#             <td>installment</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>The monthly payment owed by the borrower if the loan originates.</td>
#             </tr>
#             <tr>
#             <td>grade</td>
#             <td>String</td>
#             <td>No</td>
#             <td>LC assigned loan grade</td>
#             </tr>
#             <tr>
#             <td>subGrade</td>
#             <td>String</td>
#             <td>No</td>
#             <td>LC assigned loan subgrade</td>
#             </tr>
#             <tr>
#             <td>empLength</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Employment length in months. Possible values are whole numbers from 0 and higher. Null indicates not employed.</td>
#             </tr>
#             <tr>
#             <td>homeOwnership</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#             </tr>
#             <tr>
#             <td>annualInc</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>The annual income provided by the borrower during registration.</td>
#             </tr>
#             <tr>
#             <td>isIncV</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>Indicates if income is verified by LC</td>
#             </tr>
#             <tr>
#             <td>acceptD</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The date which the borrower accepted the offer</td>
#             </tr>
#             <tr>
#             <td>expD</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The date the listing will expire</td>
#             </tr>
#             <tr>
#             <td>listD</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The date which the borrower's application was listed on the platform.</td>
#             </tr>
#             <tr>
#             <td>creditPullD</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The date LC pulled credit for this loan</td>
#             </tr>
#             <tr>
#             <td>reviewStatusD</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The date the loan application was reviewed by LC</td>
#             </tr>
#             <tr>
#             <td>reviewStatus</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The status of the loan during the listing period. Values: APPROVED, NOT_APPROVED.</td>
#             </tr>
#             <tr>
#             <td>desc</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>Loan description provided by the borrower</td>
#             </tr>
#             <tr>
#             <td>purpose</td>
#             <td>String</td>
#             <td>No</td>
#             <td>A category provided by the borrower for the loan request. Values are: debt_consolidation, medical, home_improvement, renewable_energy, small_business, wedding, vacation, moving, house, car, major_purchase, credit_card, other</td>
#             </tr>
#             <tr>
#             <td>addrZip</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The first 3 numbers of the ZIP code provided by the borrower in the loan application.</td>
#             </tr>
#             <tr>
#             <td>addrState</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The address state provided by the borrower during loan application</td>
#             </tr>
#             <tr>
#             <td>investorCount</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of investor members who have purchased notes from this loan</td>
#             </tr>
#             <tr>
#             <td>ilsExpD</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The date and time when the loan will no longer be in the initial listing status. After this date is past, the initialListStatus below will not have any effect and the loan will be treated as a FRACTIONAL loan.</td>
#             </tr>
#             <tr>
#             <td>initialListStatus</td>
#             <td>String</td>
#             <td>No</td>
#             <td>The initial listing status of the loan. Possible values are W, F.</td>
#             </tr>
#             <tr>
#             <td>empTitle</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>Employment title</td>
#             </tr>
#             <tr>
#             <td>accNowDelinq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of accounts on which the borrower is now delinquent.</td>
#             </tr>
#             <tr>
#             <td>accOpenPast24Mths</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of trades opened in past 24 months.</td>
#             </tr>
#             <tr>
#             <td>bcOpenToBuy</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total open to buy on revolving bankcards.</td>
#             </tr>
#             <tr>
#             <td>percentBcGt75</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Percentage of all bankcard accounts &gt; 75% of limit.</td>
#             </tr>
#             <tr>
#             <td>bcUtil</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Ratio of total current balance to high credit/credit limit for all bankcard accounts.</td>
#             </tr>
#             <tr>
#             <td>dti</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>The borrower's debt to income ratio, calculated using the monthly payments on the total debt obligations, excluding mortgage, divided by self-reported monthly income.</td>
#             </tr>
#             <tr>
#             <td>delinq2Yrs</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years.</td>
#             </tr>
#             <tr>
#             <td>delinqAmnt</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>The past-due amount owed for the accounts on which the borrower is now delinquent.</td>
#             </tr>
#             <tr>
#             <td>earliestCrLine</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The date the borrower's earliest reported credit line was opened</td>
#             </tr>
#             <tr>
#             <td>ficoRangeLow</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The lower boundary of range the borrower's FICO belongs to.</td>
#             </tr>
#             <tr>
#             <td>ficoRangeHigh</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The upper boundary of range the borrower's FICO belongs to.</td>
#             </tr>
#             <tr>
#             <td>inqLast6Mths</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of inquiries by creditors during the past 6 months.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceLastDelinq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of months since the borrower's last delinquency.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceLastRecord</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of months since the last public record.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceRecentInq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent inquiry.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceRecentRevolDelinq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent revolving delinquency.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceRecentBc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent bankcard account opened.</td>
#             </tr>
#             <tr>
#             <td>mortAcc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of mortgage accounts.</td>
#             </tr>
#             <tr>
#             <td>openAcc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The Number of open credit lines in the borrower's credit file.</td>
#             </tr>
#             <tr>
#             <td>pubRec</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of derogatory public records.</td>
#             </tr>
#             <tr>
#             <td>totalBalExMort</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total credit balance excluding mortgage.</td>
#             </tr>
#             <tr>
#             <td>revolBal</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Total credit revolving balance.</td>
#             </tr>
#             <tr>
#             <td>revolUtil</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#             </tr>
#             <tr>
#             <td>totalBcLimit</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total bankcard high credit/credit limit.</td>
#             </tr>
#             <tr>
#             <td>totalAcc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>The total Number of credit lines currently in the borrower's credit file</td>
#             </tr>
#             <tr>
#             <td>totalIlHighCreditLimit</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total installment high credit/credit limit</td>
#             </tr>
#             <tr>
#             <td>numRevAccts</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of revolving accounts</td>
#             </tr>
#             <tr>
#             <td>mthsSinceRecentBcDlq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent bankcard delinquency.</td>
#             </tr>
#             <tr>
#             <td>pubRecBankruptcies</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of public record bankruptcies.</td>
#             </tr>
#             <tr>
#             <td>numAcctsEver120Ppd</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of accounts ever 120 or more days past due.</td>
#             </tr>
#             <tr>
#             <td>chargeoffWithin12Mths</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of charge-offs within 12 months.</td>
#             </tr>
#             <tr>
#             <td>collections12MthsExMed</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of collections in 12 months excluding medical collections.</td>
#             </tr>
#             <tr>
#             <td>taxLiens</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of tax liens</td>
#             </tr>
#             <tr>
#             <td>mthsSinceLastMajorDerog</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent 90-day or worse rating.</td>
#             </tr>
#             <tr>
#             <td>numSats</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of satisfactory accounts</td>
#             </tr>
#             <tr>
#             <td>numTlOpPast12m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of accounts opened in past 12 months</td>
#             </tr>
#             <tr>
#             <td>moSinRcntTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent account opened</td>
#             </tr>
#             <tr>
#             <td>totHiCredLim</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total high credit/credit limit</td>
#             </tr>
#             <tr>
#             <td>totCurBal</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total current balance of all accounts</td>
#             </tr>
#             <tr>
#             <td>avgCurBal</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Average current balance of all accounts</td>
#             </tr>
#             <tr>
#             <td>numBcTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of bankcard accounts</td>
#             </tr>
#             <tr>
#             <td>numActvBcTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active bankcard accounts</td>
#             </tr>
#             <tr>
#             <td>numBcSats</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of satisfactory bankcard accounts</td>
#             </tr>
#             <tr>
#             <td>pctTlNvrDlq</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Percent of trades never delinquent</td>
#             </tr>
#             <tr>
#             <td>numTl90gDpd24m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of accounts 90 or more days past due in last 24 months</td>
#             </tr>
#             <tr>
#             <td>numTl30dpd</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of accounts currently 30 days past due (updated in past 2 months)</td>
#             </tr>
#             <tr>
#             <td>numTl120dpd2m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of accounts currently 120 days past due (updated in past 2 months)</td>
#             </tr>
#             <tr>
#             <td>numIlTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of installment accounts</td>
#             </tr>
#             <tr>
#             <td>moSinOldIlAcct</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since oldest installment account opened</td>
#             </tr>
#             <tr>
#             <td>numActvRevTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active revolving trades</td>
#             </tr>
#             <tr>
#             <td>moSinOldRevTlOp</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since oldest revolving account opened</td>
#             </tr>
#             <tr>
#             <td>moSinRcntRevTlOp</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent revolving account opened</td>
#             </tr>
#             <tr>
#             <td>totalRevHiLim</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total revolving high credit/credit limit</td>
#             </tr>
#             <tr>
#             <td>numRevTlBalGt0</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of revolving trades with balance &gt; 0</td>
#             </tr>
#             <tr>
#             <td>numOpRevTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of open revolving accounts</td>
#             </tr>
#             <tr>
#             <td>totCollAmt</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Total collection amounts ever owed</td>
#             </tr>
#             <tr>
#             <td>fundedAmount</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>The total amount funded by investors for that loan at that point in time.</td>
#             </tr>
#             <tr>
#             <td>loanAmount</td>
#             <td>Number</td>
#             <td>No</td>
#             <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#             </tr>
#             <tr>
#             <td>applicationType</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>The loan application type. Valid values are "INDIVIDUAL" or "JOINT".</td>
#             </tr>
#             <tr>
#             <td>disbursementMethod</td>
#             <td>String</td>
#             <td>No</td>
#             <td>It will indicate the loan disbursement method. Valid values are "DIRECT_PAY" or "CASH".</td>
#             </tr>
#             <tr>
#             <td>annualIncJoint</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>The joint annual income if the applicationType is "JOINT".</td>
#             </tr>
#             <tr>
#             <td>dtiJoint</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>The joint debt to joint income ratio. This field is populated if the applicationType is "JOINT". Calculated using the monthly payments on the total debt obligations, excluding mortgage, divided by self-reported monthly income.</td>
#             </tr>
#             <tr>
#             <td>isIncVJoint</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>Indicates if joint income is verified by LC. Valid values are NOT_VERIFIED,SOURCE_VERIFIED and VERIFIED.</td>
#             </tr>
#             <tr>
#             <td>openAcc6m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of open trades in last 6 months.</td>
#             </tr>
#             <tr>
#             <td>openIl6m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active installment trades.</td>
#             </tr>
#             <tr>
#             <td>openActIl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active installment trades. This field is a replacement field for openIl6m</td>
#             </tr>
#             <tr>
#             <td>openIl12m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of installment accounts opened in past 12 months.</td>
#             </tr>
#             <tr>
#             <td>openIl24m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of installment accounts opened in past 24 months.</td>
#             </tr>
#             <tr>
#             <td>mthsSinceRcntIl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent installment accounts opened.</td>
#             </tr>
#             <tr>
#             <td>totalBalIl</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Total current balance of all installment accounts.</td>
#             </tr>
#             <tr>
#             <td>iLUtil</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Ratio of total current balance to high credit/credit limit on all install acct.</td>
#             </tr>
#             <tr>
#             <td>openRv12m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of revolving trades opened in past 12 months.</td>
#             </tr>
#             <tr>
#             <td>openRv24m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of revolving trades opened in past 24 months.</td>
#             </tr>
#             <tr>
#             <td>maxBalBc</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Maximum current balance owed on all revolving accounts.</td>
#             </tr>
#             <tr>
#             <td>allUtil</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Balance to credit limit on all trades.</td>
#             </tr>
#             <tr>
#             <td>inqFi</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of personal finance inquiries.</td>
#             </tr>
#             <tr>
#             <td>totalCuTl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of credit union trades.</td>
#             </tr>
#             <tr>
#             <td>inqLast12m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of credit inquiries in past 12 months.</td>
#             </tr>
#             <tr>
#             <td>mtgPayment</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Monthly mortgage amount.</td>
#             </tr>
#             <tr>
#             <td>housingPayment</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Borrower stated housing payment on loan application.</td>
#             </tr>
#             <tr>
#             <td>revolBalJoint</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Sum of revolving credit balance of the co-borrowers, net of duplicate balances.</td>
#             </tr>
#             <tr>
#             <td>secAppFicoRangeLow</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>FICO range (low) for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppFicoRangeHigh</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>FICO range (high) for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppEarliestCrLine</td>
#             <td>String</td>
#             <td>Yes</td>
#             <td>Earliest credit line at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppInqLast6Mths</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Credit inquiries in the last 6 months at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppMortAcc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of mortgage accounts at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppOpenAcc</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of open trades at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppRevolUtil</td>
#             <td>Number</td>
#             <td>Yes</td>
#             <td>Ratio of total current balance to high credit/credit limit for all revolving accounts.</td>
#             </tr>
#             <tr>
#             <td>secAppOpenIl6m</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active installment trades at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppOpenActIl</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of currently active installment trades at time of application for the secondary applicant. This field is a replacement field for secAppOpenIl6m</td>
#             </tr>
#             <tr>
#             <td>secAppNumRevAccts</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of revolving accounts at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppChargeoffWithin12Mths</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of charge-offs within last 12 months at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppCollections12MthsExMed</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant.</td>
#             </tr>
#             <tr>
#             <td>secAppMthsSinceLastMajorDerog</td>
#             <td>Integer</td>
#             <td>Yes</td>
#             <td>Months since most recent 90-day or worse rating at time of application for the secondary applicant.</td>
#             </tr>
#             </tbody>
#             </table>

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# Was sehen wir was haben wir. Shape, range, value range, datatype (info)

# %% [markdown]
# ## Target Metric

# %% [markdown]
# - FP - **denying the loan to a client who will end up paying in full**
# - TP - got credit pays back
# - FN - **avoid approving somebody who won't be able to repay**
# - TN - no credit at all

# %% [markdown]
# Key intrests:
# - For investors it is important to get payed back. (FP is worst)
# - For lendersclub maximum ouf impact. (FN is worst)
# - For lenders to get a credit.

# %% [markdown]
# ## Business Scenario

# %% [markdown]
# ## To-Do-List /Open Questions

# %% [markdown]
# 2 Models
# - one for lendersclub **focus** on f2 score
# - one for investors **focus** on false positive and recall
#
# - We also might need to evaluate TPR to make sure we are not declined too many qualified borrowers.

# %% [markdown]
# ## Dashboard

# %%
random_state = 100           # Ensures modeling results can be replicated
test_size = 0.3              # Train/test split
n_reduced = 10000            # Number of row items in reduced dataset (modeling)
scoring = "f1"               # modeling scoring options: "f1", "recall", "precision", "accuracy", "roc_auc"

pd.set_option('display.max_columns', 50) # Sets maximum columns displayed in tables
sns.set(style="white")                   # Sets default style for plots
# %matplotlib inline

# formatierung round 3 nachkomma tausender komma

# %% [markdown]
# # Data Mining

# %% [markdown]
# The dataset was made available to us in the second project in the newly founded Data Science Bootcamp. The data was collected and provided by the Lending Club (lendersclub.com). In total there are 42538 entries in 52 columns.

# %%
df = pd.read_csv("data/loans_2007.csv")

# %% [markdown]
# Tasks
# - Make a model to assess whether or not a new customer is likely to pay back the loan. You can use several different machine learning models.
#
# - In the accepted loans data, we have a column called "grade." It takes values from A-G (A is the best, G is the worst). The task is to build a classifier that, given some other features, can accurately categorize a loan by grade.

# %% [markdown]
# # Data Cleaning
# Purpose: Fix the inconsistencies within the data and handle the missing values

# %%
# new df for the inspections
df_insp = df

# %%
# check the shape
df_insp.shape
# Out:
# (42538, 52)

# %%
# geht an overview over datatype and missings
df_insp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42538 entries, 0 to 42537
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          42538 non-null  object
#  1   member_id                   42535 non-null  float64
#  2   loan_amnt                   42535 non-null  float64
#  3   funded_amnt                 42535 non-null  float64
#  4   funded_amnt_inv             42535 non-null  float64
#  5   term                        42535 non-null  object
#  6   int_rate                    42535 non-null  object
#  7   installment                 42535 non-null  float64
#  8   grade                       42535 non-null  object
#  9   sub_grade                   42535 non-null  object
#  10  emp_title                   39909 non-null  object
#  11  emp_length                  41423 non-null  object
#  12  home_ownership              42535 non-null  object
# ...

# %% [markdown]
# Observations:
# - there are at least 39909 entries "emp_title"
# - there are 22 object typed columns
# - the column names are readable

# %%
# check the distribution of numerical features across the sample
df_insp.describe().round(0).transpose()
# Out:
#                               count      mean       std      min       25%  \
# member_id                   42535.0  825703.0  279541.0  70473.0  638480.0
# loan_amnt                   42535.0   11090.0    7411.0    500.0    5200.0
# funded_amnt                 42535.0   10822.0    7147.0    500.0    5000.0
# funded_amnt_inv             42535.0   10140.0    7132.0      0.0    4950.0
# installment                 42535.0     323.0     209.0     16.0     166.0
# annual_inc                  42531.0   69137.0   64096.0   1896.0   40000.0
# dti                         42535.0      13.0       7.0      0.0       8.0
# delinq_2yrs                 42506.0       0.0       1.0      0.0       0.0
# inq_last_6mths              42506.0       1.0       2.0      0.0       0.0
# open_acc                    42506.0       9.0       4.0      1.0       6.0
# pub_rec                     42506.0       0.0       0.0      0.0       0.0
# ...

# %% [markdown]
# Observations:
# - in lots of columns there seems to be little ranges and few entries at all ("out_prncp", "out_prncp_inv" ...)

# %%
# check the first entries in the dataset
df_insp.head(40).transpose()
# Out:
#                                       0                1  \
# id                              1077501          1077430
# member_id                    1.2966e+06      1.31417e+06
# loan_amnt                          5000             2500
# funded_amnt                        5000             2500
# funded_amnt_inv                    4975             2500
# term                          36 months        60 months
# int_rate                         10.65%           15.27%
# installment                      162.87            59.83
# grade                                 B                C
# sub_grade                            B2               C4
# emp_title                           NaN            Ryder
# emp_length                    10+ years         < 1 year
# home_ownership                     RENT             RENT
# annual_inc                        24000            30000
# verification_status            Verified  Source Verified
# ...

# %%
# check value range
df.revol_util.value_counts()
# Out:
# 0%        1070
# 40.7%       65
# 0.2%        64
# 63%         63
# 66.6%       62
#           ...
# 37.73%       1
# 105.3%       1
# 7.64%        1
# 0.86%        1
# 62.31%       1
# Name: revol_util, Length: 1119, dtype: int64

# %% [markdown]
# Observations:
# -	“id” is just a key from Lenders Club (check for duplicates)
# -	“member_id” is just a key from Lenders Club (check for duplicates)
# -	“loan_amnt” equals “funded_amnt” (check)
# -	“term” (transform into boolen “term_is_36”)
# -	“int-rate” (transform to float)
# -	“emp_title” lots of NaN (drop)
# -	“emp_lenght” (transform into int)
# -	“home_ownership” has four values RENT, MORTAGE, OWN and OTHER (136 entries)
# -	“verification_status” has tree values “Not Verified”, “Verified” and “Source Verified” (check diffrences)
# -	“issue_d” has a lot of values always Month-Year
# -	“pymnt_plan” has only one not “n” entry “y” (drop)
# -	“purpose” there are 14 different categories (make histogram)
# -	“title” to many different values (drop)
# -	“zip_code” only 3 digits given style “100xxx” (drop)
# -	“dti” lots of missings only 2894 entries, but all in running credits
# -	“initial_list_status” only one value “f” (drop)
# -	“collections_12_mths_ex_med” only one value “0” (drop)
# -	“policy_code” only one value “1” (drop)
# -	“application_type” only one value “INDIVIDUAL” (drop)
# -	“chargeoff_within_12_mths” only one value “0” (drop)
# -	“acc_now_delinq” only for not “0” entries (drop)
# -	“delinq_amnt” only two others than “0” - 42506 at all (drop)
# - "pub_rec_bankruptcies" (flatten and transform bool "had_bankruptcy")
# -	“tax_lines” only one other than “0” (drop)
#
# Label / targets:
# - “loan_status” is going to be the label (target)
# - “grade” could be a classification label. Question which feature are important for “grade”?

# %%
df.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42538 entries, 0 to 42537
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   42538 non-null  object
#  1   term                 42535 non-null  object
#  2   int_rate             42535 non-null  object
#  3   grade                42535 non-null  object
#  4   sub_grade            42535 non-null  object
#  5   emp_title            39909 non-null  object
#  6   emp_length           41423 non-null  object
#  7   home_ownership       42535 non-null  object
#  8   verification_status  42535 non-null  object
#  9   issue_d              42535 non-null  object
#  10  loan_status          42535 non-null  object
#  11  pymnt_plan           42535 non-null  object
#  12  purpose              42535 non-null  object
#  13  title                42522 non-null  object
#  14  zip_code             42535 non-null  object
# ...

# %%
# check for appended entries
df_insp.tail()
# Out:
#                                                     id  member_id  loan_amnt  \
# 42533                                            72176    70868.0     2525.0
# 42534                                            71623    70735.0     6500.0
# 42535                                            70686    70681.0     5000.0
# 42536  Total amount funded in policy code 1: 471701350        NaN        NaN
# 42537          Total amount funded in policy code 2: 0        NaN        NaN
#
#        funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 42533       2525.0            225.0   36 months    9.33%        80.69     B
# 42534       6500.0              0.0   36 months    8.38%       204.84     A
# 42535       5000.0              0.0   36 months    7.75%       156.11     A
# 42536          NaN              NaN         NaN      NaN          NaN   NaN
# 42537          NaN              NaN         NaN      NaN          NaN   NaN
#
# ...

# %% [markdown]
# ## Drop empty, useless and one value columns

# %%
# check for duplicates if non drop
print("---id---")
print(df_insp.id.duplicated().value_counts())
print("---member_id---")
print(df_insp.member_id.duplicated().value_counts())
# Out:
# ---id---
# False    42305
# Name: id, dtype: int64
# ---member_id---
# False    42305
# Name: member_id, dtype: int64

# %%
# all of these features where the value range small (<10 diffrent entries)
drop_columns = ["id",
                "member_id",
                "pymnt_plan",
                "title",
                "zip_code",
                "initial_list_status",
                "collections_12_mths_ex_med",
                "policy_code",
                "application_type",
                "chargeoff_within_12_mths",
                "acc_now_delinq",
                "delinq_amnt",
                "tax_liens"]

# %% [markdown]
# ## Handling missing

# %%
# check for missings
missing = pd.DataFrame(df_insp.isnull().sum(),columns=['Number'])
missing['Percentage'] = round(missing.Number/df_insp.shape[0]*100,1)
missing[missing.Number!=0]
# Out:
#                       Number  Percentage
# emp_title               2591         6.1
# emp_length              1107         2.6
# title                     13         0.0
# revol_util                54         0.1
# pub_rec_bankruptcies    1222         2.9

# %%
# all 0 rows dropped
df_insp.collections_12_mths_ex_med.value_counts()
# all 0 rows dropped
df_insp.chargeoff_within_12_mths.value_counts()
# 32 rows kicked cause lots of missing entries, see above
df_insp = df_insp[df_insp.delinq_amnt.notna()]
print(f"Shape df {df.shape}")
print(f"Shape df {df_insp.shape}")

df_insp = df_insp[df_insp.collections_12_mths_ex_med.notna()]
missing = pd.DataFrame(df_insp.isnull().sum(),columns=['Number'])
missing['Percentage'] = round(missing.Number/df_insp.shape[0]*100,1)
missing[missing.Number!=0]
# Out:
# Shape df (42538, 52)
# Shape df (42305, 52)
#                       Number  Percentage
# emp_title               2591         6.1
# emp_length              1107         2.6
# title                     13         0.0
# revol_util                54         0.1
# pub_rec_bankruptcies    1222         2.9

# %%
# lots of diffrent entrys 6,2% missing (drop)
df_insp.emp_title.value_counts()
# Out:
# US Army                    138
# Bank of America            115
# IBM                         72
# AT&T                        61
# Kaiser Permanente           61
#                           ...
# Rollins Fire Sprinklers      1
# B and B Muffler              1
# Motosport Inc                1
# Paulding County DFCS         1
# Techsolutions Corp           1
# Name: emp_title, Length: 30511, dtype: int64

# %%
# fillna 2,6% with median
df_insp.emp_length.value_counts()
# Out:
# 10+ years    9347
# < 1 year     4996
# 2 years      4717
# 3 years      4346
# 4 years      3636
# 1 year       3556
# 5 years      3444
# 6 years      2368
# 7 years      1870
# 8 years      1585
# 9 years      1333
# Name: emp_length, dtype: int64

# %%
# fillna woher kommt der wert? Selbsteinschätzung, dann max-wert, sonst null 3,2%
df_insp.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    39241
# 1.0     1834
# 2.0        8
# Name: pub_rec_bankruptcies, dtype: int64

# %% [markdown]
# **Informationsverlust, lieber neues Feature "hat schon mal gezahlt, gegen hat noch nie"**

# %%
# find NaN entries "last_pymnt_d" and "last_credit_pull_d"
df_insp.last_pymnt_d.value_counts()
df_insp.last_credit_pull_d.value_counts()

# cut rows with missings
df_insp = df_insp[df_insp.last_pymnt_d.notna()]
df_insp = df_insp[df_insp.last_credit_pull_d.notna()]

# %%
# missings table
missing = pd.DataFrame(df_insp.isnull().sum(),columns=['Number'])
missing['Percentage'] = round(missing.Number/df_insp.shape[0]*100,2)
missing[missing.Number!=0]
# Out:
#                       Number  Percentage
# emp_title               2591        6.12
# emp_length              1107        2.62
# title                     13        0.03
# revol_util                54        0.13
# pub_rec_bankruptcies    1222        2.89

# %%
# lots of diffrent values no generalisation possible (drop)
df_insp.title.value_counts()
# Out:
# Debt Consolidation                                2254
# Debt Consolidation Loan                           1756
# Personal Loan                                      704
# Consolidation                                      545
# debt consolidation                                 532
#                                                   ...
# CC1                                                  1
# New Home Expenses and Investment Funding             1
# new family looking to start with a clean slate       1
# credit consoladation                                 1
# Moving and Vehicle Expenses                          1
# Name: title, Length: 21127, dtype: int64

# %% [markdown]
# ## Replace missing

# %% [markdown]
# Purpose: We handled the missigs, as suggested in this article: https://www.datasciencecentral.com/forum/topics/how-to-deal-with-missing-data.

# %% [markdown]
# ### emp_length

# %%
df_insp.emp_length.value_counts()
# Out:
# 10+ years    9347
# < 1 year     4996
# 2 years      4717
# 3 years      4346
# 4 years      3636
# 1 year       3556
# 5 years      3444
# 6 years      2368
# 7 years      1870
# 8 years      1585
# 9 years      1333
# Name: emp_length, dtype: int64

# %%
# fillna with median 2,6%
df_a = df_insp.copy()

# fillna woher kommt der wert? Selbsteinschätzung, dann max-wert, sonst null 3,2%
df_a.emp_length = df_a.emp_length.str.replace("< 1 year", "0 year")
df_a.emp_length = df_a.emp_length.str.split(' ').str[-2]
df_a.emp_length = df_a.emp_length.replace("10+", "10")
df_a.emp_length.value_counts()
# Out:
# 10    9347
# 0     4996
# 2     4717
# 3     4346
# 4     3636
# 1     3556
# 5     3444
# 6     2368
# 7     1870
# 8     1585
# 9     1333
# Name: emp_length, dtype: int64

# %% [markdown]
# Here we use the median due to the distribution

# %%
median_emplenght = df_a.emp_length.median()
print(f"The median is of emp_length is {median_emplenght}")
print("The distribution is shown in the plot")

# replace missings with median
df_a.emp_length.fillna(median_emplenght,inplace=True)
df_a.emp_length = df_a.emp_length.astype(int)
df_a.emp_length.hist(density=1);
# Out:
# The median is of emp_length is 4.0
# The distribution is shown in the plot

# %%
df_a.emp_length.value_counts()
# Out:
# 10    9347
# 0     4996
# 4     4743
# 2     4717
# 3     4346
# 1     3556
# 5     3444
# 6     2368
# 7     1870
# 8     1585
# 9     1333
# Name: emp_length, dtype: int64

# %%
# rewrite to df_insp
df_insp.emp_length = df_a.emp_length

# %% [markdown]
# ### pub_rec_bankruptcies

# %%
df_insp.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    39241
# 1.0     1834
# 2.0        8
# Name: pub_rec_bankruptcies, dtype: int64

# %%
# no info about bankruptcie will be interpreted as none
df_insp.pub_rec_bankruptcies = df_insp.pub_rec_bankruptcies.fillna(0.0).astype('uint8')
# flatten the entries (8) that have amount of 2 new values 0 or 1
df_insp.pub_rec_bankruptcies = df_insp.pub_rec_bankruptcies.apply(lambda x: 1 if x > 0 else 0)
df_insp.pub_rec_bankruptcies.value_counts()
# Out:
# 0    40463
# 1     1842
# Name: pub_rec_bankruptcies, dtype: int64

# %% [markdown]
# ### revol_util

# %%
df_insp.revol_util.fillna(0, inplace=True)

missing = pd.DataFrame(df_insp.isnull().sum(),columns=['Number'])
missing['Percentage'] = round(missing.Number/df_insp.shape[0]*100,2)
missing[missing.Number!=0]
# Out:
#            Number  Percentage
# emp_title    2591        6.12
# title          13        0.03

# %% [markdown]
# ## Drop Columns

# %%
# drops: all of these features value range is either complete 0 or NaN
drop_columns_zeros = ["emp_title"]

drop_columns += drop_columns_zeros

# %%
df_insp.drop(columns=drop_columns,inplace=True,axis=1)

# %% [markdown]
# ## Change Value Type to usable values (object types)

# %%
term = bool 
int_rate = float
verification_status = bool ?
zipcode = int last three are "xxx"
# Out:
#   File "<ipython-input-34-acdae0827116>", line 3
#     verification_status = bool ?
#                                ^
# SyntaxError: invalid syntax

# %%
df_insp.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42305 entries, 0 to 42449
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   term                 42305 non-null  object
#  1   int_rate             42305 non-null  object
#  2   grade                42305 non-null  object
#  3   sub_grade            42305 non-null  object
#  4   emp_title            39714 non-null  object
#  5   home_ownership       42305 non-null  object
#  6   verification_status  42305 non-null  object
#  7   issue_d              42305 non-null  object
#  8   loan_status          42305 non-null  object
#  9   purpose              42305 non-null  object
#  10  addr_state           42305 non-null  object
#  11  earliest_cr_line     42305 non-null  object
#  12  revol_util           42305 non-null  object
#  13  last_pymnt_d         42305 non-null  object
#  14  last_credit_pull_d   42305 non-null  object
# ...

# %% [markdown]
# ## Observations

# %%
# data loss
print(f'{round((1-df_insp.shape[0]/df.shape[0])*100,3)}% data loss after cleaning')
print(df_insp.shape)
# Out:
# 0.548% data loss after cleaning
# (42305, 39)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Target Variable (groupby)

# %% [markdown]
# ## Ouliners    min max

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Preprocessing (Train/Test Split and Pipeline)

# %%
stratify by loan_status

# %% [markdown]
# ## Train/test and preprocessing (full dataset)
# ## Train/test and preprocessing (balanced dataset)
# ## Train/test and preprocessing (reduced dataset)

# %% [markdown]
# # 7 Predictive Modeling: Classification ("state")
# ## LogReg (with GridSearch)
# ## Random Forest Classifier
# ## Support Vector Classifier
# ## AdaBoost (Future Work)
# ## XGBoost (Future Work)
# ## Ensemble Test Multiple Models
# ## Optimization (Future Work): RandomizedSearchCV
# ## Optimization (Future Work): Training and Predicting Pipeline

# %% [markdown]
# # 8 Predictive Modeling (Future Work): Regression ("usd_pledged")
# ## Train/test split and preprocessing pipeline
# ## Linear regression (OLS)
# ## Linear regression (Scikit Learn)
# ## KNeighborsRegression
# ## RANSACRegressor

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Findings and Recommendations
# ## Raw results
# ## Findings
# ## Recommendations

# %% [markdown]
# # Future Work

# %% [markdown]
# # References and Useful Links/Blogs
# ## References
# ## Useful Links/Blogs
